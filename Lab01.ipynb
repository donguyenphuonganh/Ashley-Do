# %% [markdown]
# <a href="https://colab.research.google.com/github/donguyenphuonganh/Ashley-Do/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install opencv-python
# %pip install matplotlib
# %pip install numpy
# %pip install scikit-learn

# %%
import cv2
cv2.__version__
# Out:
# '4.10.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow
imgpath = '/content/drive/MyDrive/ImgProcessing/TigerImg.jpg'
image = cv2.imread(imgpath)
shape = image.shape
size = image.size
print(shape)
print(size)
cv2_imshow(image)
# Out:
# (315, 600, 3)
# 567000
# <PIL.Image.Image image mode=RGB size=600x315>

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
plt.imshow(image[::-1, ::-1, ::-1])

# %%
crop = image[100:300, 100:300]
plt.imshow(crop[:,:,::-1])

# %%
cv2.imwrite("test.jpg", image)
# Out:
# True

# %%
img = image.copy()
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x315>

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=600x315>

# %%
img_resized = cv2.resize(img, (100,200))
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=100x200>

# %%
R, G, B = img[:, :, 0], img[:, :, 1], img[:, :, 2]
gray_img = 0.2989 * R + 0.587 * G + 0.114 * B
plt.imshow(gray_img, cmap='gray')

# %%
from skimage import color
from skimage import io
img = io.imread('/content/drive/MyDrive/ImgProcessing/TigerImg.jpg')
gray_img = color.rgb2gray(img)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=600x315>
